# %%
import pandas as pd

# %%
df = pd.read_csv("mlb_2021_batting.csv")

# %%
print(df.shape)
df.head()
# Out:
# (1723, 30)
#    Rk                     Name  Age   Tm  Lg    G   PA   AB   R    H  ...  \
# 0   1  Fernando Abad*\abadfe01   35  BAL  AL    2    0    0   0    0  ...
# 1   2    Cory Abbott\abbotco01   25  CHC  NL    8    3    3   0    1  ...
# 2   3   Albert Abreu\abreual01   25  NYY  AL    3    0    0   0    0  ...
# 3   4    Bryan Abreu\abreubr01   24  HOU  AL    1    0    0   0    0  ...
# 4   5     José Abreu\abreujo02   34  CHW  AL  152  659  566  86  148  ...
#
#      SLG    OPS   OPS+   TB  GDP  HBP  SH  SF  IBB  Pos Summary
# 0    NaN    NaN    NaN    0    0    0   0   0    0            1
# 1  0.333  0.667   81.0    1    0    0   0   0    0          /1H
# 2    NaN    NaN    NaN    0    0    0   0   0    0            1
# 3    NaN    NaN    NaN    0    0    0   0   0    0            1
# 4  0.481  0.831  124.0  272   28   22   0  10    3        *3D/5
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1723 entries, 0 to 1722
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rk           1723 non-null   int64
#  1   Name         1723 non-null   object
#  2   Age          1723 non-null   int64
#  3   Tm           1723 non-null   object
#  4   Lg           1723 non-null   object
#  5   G            1723 non-null   int64
#  6   PA           1723 non-null   int64
#  7   AB           1723 non-null   int64
#  8   R            1723 non-null   int64
#  9   H            1723 non-null   int64
#  10  2B           1723 non-null   int64
#  11  3B           1723 non-null   int64
#  12  HR           1723 non-null   int64
#  13  RBI          1723 non-null   int64
#  14  SB           1723 non-null   int64
#  15  CS           1723 non-null   int64
#  16  BB           1723 non-null   int64
#  17  SO           1723 non-null   int64
#  18  BA           1252 non-null   float64
# ...

# %%
pd.isnull(df['BA'])
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1718    False
# 1719    False
# 1720    False
# 1721    False
# 1722    False
# Name: BA, Length: 1723, dtype: bool

# %%
df.columns
# Out:
# Index(['Rk', 'Name', 'Age', 'Tm', 'Lg', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B',
#        'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+',
#        'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB', 'Pos Summary'],
#       dtype='object')

# %%
df  = df.rename(columns={'BA':'batting_avg','G':'games_played', 'AB':'at_bats'})

# %%
df.columns
# Out:
# Index(['Rk', 'Name', 'Age', 'Tm', 'Lg', 'games_played', 'PA', 'at_bats', 'R',
#        'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'batting_avg',
#        'OBP', 'SLG', 'OPS', 'OPS+', 'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB',
#        'Pos Summary'],
#       dtype='object')

# %%
df_games = df.loc[df['games_played']>10]

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 4 to 1722
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rk            1085 non-null   int64
#  1   Name          1085 non-null   object
#  2   Age           1085 non-null   int64
#  3   Tm            1085 non-null   object
#  4   Lg            1085 non-null   object
#  5   games_played  1085 non-null   int64
#  6   PA            1085 non-null   int64
#  7   AB            1085 non-null   int64
#  8   R             1085 non-null   int64
#  9   H             1085 non-null   int64
#  10  2B            1085 non-null   int64
#  11  3B            1085 non-null   int64
#  12  HR            1085 non-null   int64
#  13  RBI           1085 non-null   int64
#  14  SB            1085 non-null   int64
#  15  CS            1085 non-null   int64
#  16  BB            1085 non-null   int64
#  17  SO            1085 non-null   int64
# ...

# %%
df_avg = df_games.loc[df_games['at_bats']>60]

# %%
df_avg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600 entries, 4 to 1722
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rk            600 non-null    int64
#  1   Name          600 non-null    object
#  2   Age           600 non-null    int64
#  3   Tm            600 non-null    object
#  4   Lg            600 non-null    object
#  5   games_played  600 non-null    int64
#  6   PA            600 non-null    int64
#  7   at_bats       600 non-null    int64
#  8   R             600 non-null    int64
#  9   H             600 non-null    int64
#  10  2B            600 non-null    int64
#  11  3B            600 non-null    int64
#  12  HR            600 non-null    int64
#  13  RBI           600 non-null    int64
#  14  SB            600 non-null    int64
#  15  CS            600 non-null    int64
#  16  BB            600 non-null    int64
#  17  SO            600 non-null    int64
# ...

# %%
df_avg.sort_values('batting_avg', ascending=False)
# Out:
#         Rk                       Name  Age   Tm   Lg  games_played   PA  \
# 1384  1385  Frank Schwindel\schwifr01   29  CHC   NL            56  239
# 1282  1283      Luis Robert\roberlu01   23  CHW   AL            68  296
# 1576  1577      Trea Turner\turnetr01   28  LAD   NL            52  226
# 1565  1566       Mike Trout\troutmi01   29  LAA   AL            36  146
# 1574  1575      Trea Turner\turnetr01   28  TOT   NL           148  646
# ...    ...                        ...  ...  ...  ...           ...  ...
# 436    437       Drew Ellis\ellisdr01   25  ARI   NL            28   83
# 346    347   Jonathan Davis\davisjo05   29  TOT   AL            64  103
# 863    864   Domingo Leyba#\leybado01   25  TOT  MLB            34   96
# 1128  1129   Cristian Pache\pachecr01   22  ATL   NL            22   68
# 202    203   Walker Buehler\buehlwa01   26  LAD   NL            34   82
#
#       at_bats    R    H  ...    SLG    OPS   OPS+   TB  GDP  HBP  SH  SF  IBB  \
# ...
